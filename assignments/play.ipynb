# %%
# !anaconda -V
# Out:
# anaconda Command line client (version 1.11.3)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Now let's draw a sin wave.

# %%
ax1 = plt.subplot(2, 1, 1)
x = np.linspace(0, 10, 100)
y = np.sin(x)
ax1.plot(x, y)
